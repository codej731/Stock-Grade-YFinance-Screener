# %%
"""
import pandas as pd
import yfinance as yf
from finvizfinance.screener.overview import Overview

def get_combined_top_stocks(countries=['USA', 'Canada'], limit_per_country=100):
    all_stocks = []
    
    for country in countries:
        print(f"Fetching top rated stocks for: {country}...")
        
        try:
            foverview = Overview()
            
            # Use the correct filter syntax we found earlier
            filters_dict = {
                'Analyst Recom.': 'Strong Buy (1)',
                'Country': country
            }
            foverview.set_filter(filters_dict=filters_dict)
            
            # Get results
            df_results = foverview.screener_view()
            
            if not df_results.empty:
                df_results['Source_Country'] = country
                all_stocks.append(df_results)
            else:
                print(f"   No stocks found for {country}.")
                
        except Exception as e:
            print(f"   Error fetching {country}: {e}")

    if not all_stocks:
        print("\nNo stocks found from any country.")
        return pd.DataFrame()

    # Combine all results
    combined_df = pd.concat(all_stocks, ignore_index=True)
    
    # --- FIX STARTS HERE ---
    # 1. Inspect available columns to avoid guessing
    available_columns = combined_df.columns.tolist()
    print(f"\nDebug: Columns found in data: {available_columns}")

    # 2. Determine which 'Recommendation' column name is being used (if any)
    recom_col = None
    if 'Recom' in available_columns:
        recom_col = 'Recom'
    elif 'Analyst Recom' in available_columns:
        recom_col = 'Analyst Recom'
        
    # 3. Sort if we found the column
    if recom_col:
        combined_df = combined_df.sort_values(by=recom_col, ascending=True)

    # 4. safely build the list of columns to return
    # We only include columns that actually exist in 'available_columns'
    desired_cols = ['Ticker', 'Company', 'Sector', 'Price', 'Source_Country']
    
    # Add the recommendation column to our list if it exists
    if recom_col:
        desired_cols.append(recom_col)

    # Filter columns safely
    final_cols = [c for c in desired_cols if c in available_columns]
    
    return combined_df[final_cols].head(limit_per_country * len(countries))

# --- Usage ---
top_north_america = get_combined_top_stocks(['USA', 'Canada'])

if not top_north_america.empty:
    print(f"\nFound {len(top_north_america)} stocks.")
    print(top_north_america)
    
    # Get tickers
    ticker_list = top_north_america['Ticker'].tolist()
    print(f"\nTicker List: {ticker_list}")
else:
    print("DataFrame is empty.")
"""
# Out:
# '\nimport pandas as pd\nimport yfinance as yf\nfrom finvizfinance.screener.overview import Overview\n\ndef get_combined_top_stocks(countries=[\'USA\', \'Canada\'], limit_per_country=100):\n    all_stocks = []\n\n    for country in countries:\n        print(f"Fetching top rated stocks for: {country}...")\n\n        try:\n            foverview = Overview()\n\n            # Use the correct filter syntax we found earlier\n            filters_dict = {\n                \'Analyst Recom.\': \'Strong Buy (1)\',\n                \'Country\': country\n            }\n            foverview.set_filter(filters_dict=filters_dict)\n\n            # Get results\n            df_results = foverview.screener_view()\n\n            if not df_results.empty:\n                df_results[\'Source_Country\'] = country\n                all_stocks.append(df_results)\n            else:\n                print(f"   No stocks found for {country}.")\n\n        except Exception as e:\n            print(f"   Error fetching {country}: {e}")\n\n    if not all_stocks:\n        print("\nNo stocks found from any country.")\n        return pd.DataFrame()\n\n    # Combine all results\n    combined_df = pd.concat(all_stocks, ignore_index=True)\n\n    # --- FIX STARTS HERE ---\n    # 1. Inspect available columns to avoid guessing\n    available_columns = combined_df.columns.tolist()\n    print(f"\nDebug: Columns found in data: {available_columns}")\n\n    # 2. Determine which \'Recommendation\' column name is being used (if any)\n    recom_col = None\n    if \'Recom\' in available_columns:\n        recom_col = \'Recom\'\n    elif \'Analyst Recom\' in available_columns:\n        recom_col = \'Analyst Recom\'\n\n    # 3. Sort if we found the column\n    if recom_col:\n        combined_df = combined_df.sort_values(by=recom_col, ascending=True)\n\n    # 4. safely build the list of columns to return\n    # We only include columns that actually exist in \'available_columns\'\n    desired_cols = [\'Ticker\', \'Company\', \'Sector\', \'Price\', \'Source_Country\']\n\n    # Add the recommendation column to our list if it exists\n    if recom_col:\n        desired_cols.append(recom_col)\n\n    # Filter columns safely\n    final_cols = [c for c in desired_cols if c in available_columns]\n\n    return combined_df[final_cols].head(limit_per_country * len(countries))\n\n# --- Usage ---\ntop_north_america = get_combined_top_stocks([\'USA\', \'Canada\'])\n\nif not top_north_america.empty:\n    print(f"\nFound {len(top_north_america)} stocks.")\n    print(top_north_america)\n\n    # Get tickers\n    ticker_list = top_north_america[\'Ticker\'].tolist()\n    print(f"\nTicker List: {ticker_list}")\nelse:\n    print("DataFrame is empty.")\n'

# %%
import pandas as pd
from finvizfinance.screener.overview import Overview
#Top picks for Canada with refined filtering
def get_filtered_picks(countries=['Canada'], limit_per_country=200):
    all_stocks = []
    
    for country in countries:
        print(f"Fetching candidates for: {country}...")
        
        try:
            foverview = Overview()
            
            # --- STEP 1: Broaden the initial search ---
            # We ask for 'Buy or better' to get a mix of Strong Buys (1.0) and regular Buys (2.0)
            filters_dict = {
                'Analyst Recom.': 'Buy or better',
                'Country': country
            }
            foverview.set_filter(filters_dict=filters_dict)
            
            # Get results
            df_results = foverview.screener_view()
            
            if not df_results.empty:
                df_results['Source_Country'] = country
                all_stocks.append(df_results)
            else:
                print(f"   No stocks found for {country}.")
                
        except Exception as e:
            print(f"   Error fetching {country}: {e}")

    if not all_stocks:
        print("\nNo stocks found from any country.")
        return pd.DataFrame()

    # Combine all results
    combined_df = pd.concat(all_stocks, ignore_index=True)
    
    # --- STEP 2: The "Option 2" Pandas Filter ---
    
    # A. Identify the correct column name (usually 'Recom' or 'Analyst Recom')
    cols = combined_df.columns.tolist()
    recom_col = 'Recom' if 'Recom' in cols else 'Analyst Recom'
    
    if recom_col in cols:
        # B. Convert column to numbers (force any text to become NaN)
        combined_df[recom_col] = pd.to_numeric(combined_df[recom_col], errors='coerce')
        
        # C. APPLY THE STRICT FILTER
        # Logic: 1.0 = Strong Buy, 2.0 = Buy, 3.0 = Hold.
        # We keep anything <= 2.5 to strictly exclude 'Hold' (3.0) and worse.
        print(f"\nFiltering out 'Hold' or worse (Rating > 2.0)...")
        combined_df = combined_df[combined_df[recom_col] <= 2.0]
        
        # D. Sort by best rating
        combined_df = combined_df.sort_values(by=recom_col, ascending=True)

    # Clean up columns for display
    desired_cols = ['Ticker', 'Company', 'Sector', 'Price', 'Source_Country', recom_col]
    final_cols = [c for c in desired_cols if c in combined_df.columns]
    
    return combined_df[final_cols].head(limit_per_country * len(countries))

# --- Usage ---
top_picks = get_filtered_picks(['Canada'])

if not top_picks.empty:
    print(f"\nFound {len(top_picks)} 'Buy' rated stocks.")
    
    # --- STEP 3: The View Fix ---
    # This forces VS Code/Terminal to show ALL rows
    pd.set_option('display.max_rows', None)
    
    print(top_picks)
    
    # Get tickers
    ticker_list = top_picks['Ticker'].tolist()
    #print(f"\nTicker List: {ticker_list}") # Optional: Uncomment to see list
else:
    print("DataFrame is empty.")
# Out:
# Fetching candidates for: Canada...
# [Info] loading page [###########################---] 8/9
# Found 163 'Buy' rated stocks.
#     Ticker                                Company                  Sector  \
# 0     ABCL                AbCellera Biologics Inc              Healthcare
# 1      ACB                    Aurora Cannabis Inc              Healthcare
# 2     ACHV              Achieve Life Sciences Inc              Healthcare
# 3     ADUR           Aduro Clean Technologies Inc             Industrials
# 4      AEM                 Agnico Eagle Mines Ltd         Basic Materials
# 5       AG      First Majestic Silver Corporation         Basic Materials
# 6      AGI                        Alamos Gold Inc         Basic Materials
# 7      ALM                 Almonty Industries Inc         Basic Materials
# 8      ASM          Avino Silver & Gold Mines Ltd         Basic Materials
# 9      ATS                        ATS Corporation             Industrials
# 10    AUPH            Aurinia Pharmaceuticals Inc              Healthcare
# 11    AUST                       Austin Gold Corp         Basic Materials
# 12     AVX                AVAX One Technology Ltd               Financial
# 13      AZ           A2Z Cust2Mate Solutions Corp              Technology
# 14       B                    Barrick Mining Corp         Basic Materials
# 15     BBU       Brookfield Business Partners L.P             Industrials
# 16     BCE                                BCE Inc  Communication Services
# 17    BCTX             BriaCell Therapeutics Corp              Healthcare
# 18    BGSI                Boyd Group Services Inc       Consumer Cyclical
# 19    BHST                BioHarvest Sciences Inc      Consumer Defensive
# 20    BITF                           Bitfarms Ltd               Financial
# 21      BN                 Brookfield Corporation               Financial
# 22    BRAG                 Bragg Gaming Group Inc       Consumer Cyclical
# 23     BTE                     Baytex Energy Corp                  Energy
# 24     BTG                            B2gold Corp         Basic Materials
# 25     BTQ                  BTQ Technologies Corp              Technology
# 26     CAE                                Cae Inc             Industrials
# 27     CCJ                            Cameco Corp                  Energy
# 28    CGAU                      Centerra Gold Inc         Basic Materials
# 29    CIGI       Colliers International Group Inc             Real Estate
# 30     CLS                         Celestica, Inc              Technology
# 31     CNI           Canadian National Railway Co             Industrials
# 32     CNL                  Collective Mining Ltd         Basic Materials
# 33     CNQ         Canadian Natural Resources Ltd                  Energy
# 34      CP   Canadian Pacific Kansas City Limited             Industrials
# 35    CRDL               Cardiol Therapeutics Inc              Healthcare
# 36    CRON                       Cronos Group Inc              Healthcare
# 37     CVE                     Cenovus Energy Inc                  Energy
# 38    CYBN                              Cybin Inc              Healthcare
# 39    DCBO                             Docebo Inc              Technology
# 40    DEFT                  DeFi Technologies Inc               Financial
# 41    DFSC                DEFSEC Technologies Inc             Industrials
# 42     DNN                     Denison Mines Corp                  Energy
# 43    DOOO                                BRP Inc       Consumer Cyclical
# 100    NOA  North American Construction Group Ltd                  Energy
# 101    NTR                            Nutrien Ltd         Basic Materials
# 102    NXE                      NexGen Energy Ltd                  Energy
# 103    OBE                    Obsidian Energy Ltd                  Energy
# 104    OGI                  Organigram Global Inc              Healthcare
# 105   ONCY                Oncolytics Biotech, Inc              Healthcare
# 106     OR                       OR Royalties Inc         Basic Materials
# 107   ORLA                        Orla Mining Ltd         Basic Materials
# 108   PAAS               Pan American Silver Corp         Basic Materials
# 109   PAPL                Pineapple Financial Inc               Financial
# 110    PBA           Pembina Pipeline Corporation                  Energy
# 111    PDS                Precision Drilling Corp                  Energy
# 112    PLG              Platinum Group Metals Ltd         Basic Materials
# 113    PMN               ProMIS Neurosciences Inc              Healthcare
# 114   POET                  POET Technologies Inc              Technology
# 115   PROF                  Profound Medical Corp              Healthcare
# 116   QNTM                  Quantum BioPharma Ltd              Healthcare
# 117    QSR    Restaurant Brands International Inc       Consumer Cyclical
# 118    RCI              Rogers Communications Inc  Communication Services
# 119   RPTX                Repare Therapeutics Inc              Healthcare
# 120     RY                   Royal Bank Of Canada               Financial
# 121     SA                    Seabridge Gold, Inc         Basic Materials
# 122   SANG       Sangoma Technologies Corporation              Technology
# 123   SHOP                            Shopify Inc              Technology
# 124    SII                             Sprott Inc               Financial
# 125    SLF                Sun Life Financial, Inc               Financial
# 126    SLI                   Standard Lithium Ltd         Basic Materials
# 127   SLSR                  Solaris Resources Inc         Basic Materials
# 128   SNDL                               SNDL Inc      Consumer Defensive
# 129    STN                            Stantec Inc             Industrials
# 130     SU                     Suncor Energy, Inc                  Energy
# 131   SUUN                  PowerBank Corporation               Utilities
# 132    SVM                  Silvercorp Metals Inc         Basic Materials
# 133    TAC                         Transalta Corp               Utilities
# 134    TCX                            Tucows, Inc              Technology
# 135     TD                  Toronto Dominion Bank               Financial
# 136   TECK                     Teck Resources Ltd         Basic Materials
# 137   TFII                  TFI International Inc             Industrials
# 138   TFPM       Triple Flag Precious Metals Corp         Basic Materials
# 139    TGB                       Taseko Mines Ltd         Basic Materials
# 140    THM     International Tower Hill Mines Ltd         Basic Materials
# 141    TMC             TMC the metals company Inc         Basic Materials
# 142    TRI                   Thomson-Reuters Corp             Industrials
# 143    TRP                  TC Energy Corporation                  Energy
# 144    TRX                          TRX Gold Corp         Basic Materials
# 145   TSAT                           Telesat Corp              Technology
# 146     TU                             Telus Corp  Communication Services
# 147   UROY                   Uranium Royalty Corp                  Energy
# 148   USAS          Americas Gold and Silver Corp         Basic Materials
# 149   USGO                    U.S. GoldMining Inc         Basic Materials
# 150   VBNK                              VersaBank               Financial
# 151    VET                   Vermilion Energy Inc                  Energy
# 152   VMAR         Vision Marine Technologies Inc       Consumer Cyclical
# 153   VOXR                       Vox Royalty Corp         Basic Materials
# 154   VZLA                     Vizsla Silver Corp         Basic Materials
# 155    WCN                  Waste Connections Inc             Industrials
# 156    WFG            West Fraser Timber Co., Ltd         Basic Materials
# 157    WPM           Wheaton Precious Metals Corp         Basic Materials
# 112    2.45         Canada
# 113    6.76         Canada
# 114    4.95         Canada
# 115    6.60         Canada
# 116    9.70         Canada
# 117   72.39         Canada
# 118   39.12         Canada
# 119    2.18         Canada
# 120  154.09         Canada
# 121   27.93         Canada
# 122    5.22         Canada
# 123  158.64         Canada
# 124   91.59         Canada
# 125   59.12         Canada
# 126    4.19         Canada
# 127    7.90         Canada
# 128    1.76         Canada
# 129   96.56         Canada
# 130   44.78         Canada
# 131    1.61         Canada
# 132    7.82         Canada
# 133   14.55         Canada
# 134   21.67         Canada
# 135   83.93         Canada
# 136   42.89         Canada
# 137   87.49         Canada
# 138   33.49         Canada
# 139    5.28         Canada
# 140    1.94         Canada
# 141    6.96         Canada
# 142  135.43         Canada
# 143   54.72         Canada
# 144    0.74         Canada
# 145   26.05         Canada
# 146   13.15         Canada
# 147    3.72         Canada
# 148    4.44         Canada
# 149    9.87         Canada
# 150   12.10         Canada
# 151    9.27         Canada
# 152    1.23         Canada
# 153    4.79         Canada
# 154    5.07         Canada
# 155  176.55         Canada
# 156   61.50         Canada
# 157  110.05         Canada
# 158    1.78         Canada
# 159    2.45         Canada
# 160   44.72         Canada
# 161    0.65         Canada
# 162    3.42         Canada
# c:\Users\jdcc3\AppData\Local\Programs\Python\Python313\Lib\site-packages\finvizfinance\screener\base.py:134: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat([df, pd.DataFrame(frame)], ignore_index=True)

# %%
import pandas as pd
from finvizfinance.screener.overview import Overview

def get_filtered_picks(countries=['USA'], limit_per_country=5000):
    all_stocks = []
    
    for country in countries:
        print(f"Fetching candidates for: {country}...")
        
        try:
            foverview = Overview()
            
            # --- STEP 1: Broaden the initial search ---
            # We ask for 'Buy or better' to get a mix of Strong Buys (1.0) and regular Buys (2.0)
            filters_dict = {
                'Analyst Recom.': 'Buy or better',
                'Country': country
            }
            foverview.set_filter(filters_dict=filters_dict)
            
            # Get results
            df_results = foverview.screener_view()
            
            if not df_results.empty:
                df_results['Source_Country'] = country
                all_stocks.append(df_results)
            else:
                print(f"   No stocks found for {country}.")
                
        except Exception as e:
            print(f"   Error fetching {country}: {e}")

    if not all_stocks:
        print("\nNo stocks found from any country.")
        return pd.DataFrame()

    # Combine all results
    combined_df = pd.concat(all_stocks, ignore_index=True)
    
    # --- STEP 2: The "Option 2" Pandas Filter ---
    
    # A. Identify the correct column name (usually 'Recom' or 'Analyst Recom')
    cols = combined_df.columns.tolist()
    recom_col = 'Recom' if 'Recom' in cols else 'Analyst Recom'
    
    if recom_col in cols:
        # B. Convert column to numbers (force any text to become NaN)
        combined_df[recom_col] = pd.to_numeric(combined_df[recom_col], errors='coerce')
        
        # C. APPLY THE STRICT FILTER
        # Logic: 1.0 = Strong Buy, 2.0 = Buy, 3.0 = Hold.
        # We keep anything <= 2.5 to strictly exclude 'Hold' (3.0) and worse.
        print(f"\nFiltering out 'Hold' or worse (Rating > 2.0)...")
        combined_df = combined_df[combined_df[recom_col] < 1.5]
        
        # D. Sort by best rating
        combined_df = combined_df.sort_values(by=recom_col, ascending=True)

    # Clean up columns for display
    desired_cols = ['Ticker', 'Company', 'Sector', 'Price', 'Source_Country', recom_col]
    final_cols = [c for c in desired_cols if c in combined_df.columns]
    
    return combined_df[final_cols].head(limit_per_country * len(countries))

# --- Usage ---
top_picks = get_filtered_picks(['USA'])

if not top_picks.empty:
    print(f"\nFound {len(top_picks)} 'Buy' rated stocks.")
    
    # --- STEP 3: The View Fix ---
    # This forces VS Code/Terminal to show ALL rows
    #pd.set_option('display.max_rows', None)
    
    print(top_picks)
    
    # Get tickers
    ticker_list = top_picks['Ticker'].tolist()
    #print(f"\nTicker List: {ticker_list}") # Optional: Uncomment to see list
else:
    print("DataFrame is empty.")
# Out:
# Fetching candidates for: USA...
# [Info] loading page [##############################] 149/150
# Found 2000 'Buy' rated stocks.
#       Ticker                                        Company  \
# 0          A                       Agilent Technologies Inc
# 1         AA                                     Alcoa Corp
# 2        AAL                    American Airlines Group Inc
# 3       AAOI                    Applied Optoelectronics Inc
# 4       AAON                                       AAON Inc
# 5       AAPL                                      Apple Inc
# 6       AARD                      Aardvark Therapeutics Inc
# 7       ABAT            American Battery Technology Company
# 8       ABBV                                     Abbvie Inc
# 9       ABCB                                 Ameris Bancorp
# 10      ABEO                        Abeona Therapeutics Inc
# 11       ABL                   Abacus Global Management Inc
# 12       ABM                             ABM Industries Inc
# 13      ABOS                     Acumen Pharmaceuticals Inc
# 14      ABSI                                     Absci Corp
# 15       ABT                            Abbott Laboratories
# 16      ABUS                         Arbutus Biopharma Corp
# 17       ACA                                     Arcosa Inc
# 18      ACAD                     Acadia Pharmaceuticals Inc
# 19      ACCO                        Acco Brands Corporation
# 20      ACCS                            ACCESS Newswire Inc
# 21      ACEL                        Accel Entertainment Inc
# 22      ACET                                 Adicet Bio Inc
# 23      ACFN                               Acorn Energy Inc
# 24      ACHC                  Acadia Healthcare Company Inc
# 25      ACHR                            Archer Aviation Inc
# 26       ACI                       Albertsons Companies Inc
# 27      ACIC                American Coastal Insurance Corp
# 28      ACIW                              ACI Worldwide Inc
# 29      ACLS                       Axcelis Technologies Inc
# 30      ACLX                                    Arcellx Inc
# 31       ACM                                          AECOM
# 32      ACMR                               ACM Research Inc
# 33      ACNB                                      ACNB Corp
# 34      ACNT                           Ascent Industries Co
# 35      ACOG                            Alpha Cognition Inc
# 36      ACON                                   Aclarion Inc
# 37       ACR                   ACRES Commercial Realty Corp
# 38      ACRS                       Aclaris Therapeutics Inc
# 39      ACRV                       Acrivon Therapeutics Inc
# 40       ACT                             Enact Holdings Inc
# 41      ACTG                           Acacia Research Corp
# 42      ACTU                       Actuate Therapeutics Inc
# 43       ACU                               Acme United Corp
# 44      ACVA                               ACV Auctions Inc
# 45      ACXP                      Acurx Pharmaceuticals Inc
# 46        AD               Array Digital Infrastructure Inc
# 47      ADAM                               Adamas Trust Inc
# 48      ADBE                                      Adobe Inc
# 49       ADC                              Agree Realty Corp
# 50      ADEA                                      Adeia Inc
# 51       ADI                             Analog Devices Inc
# 52      ADIL                      Adial Pharmaceuticals Inc
# 53      ADMA                             Adma Biologics Inc
# 54      ADNT                                     Adient plc
# 55      ADPT                  Adaptive Biotechnologies Corp
# 56      ADSK                                   Autodesk Inc
# 57       ADT                                        ADT Inc
# 58      ADTN                            ADTRAN Holdings Inc
# 59      ADTX                                     Aditxt Inc
# 60      ADUS                     Addus HomeCare Corporation
# 61       ADV                        Advantage Solutions Inc
# 62      ADVM                    Adverum Biotechnologies Inc
# 63       AEE                                    Ameren Corp
# 64      AEIS                 Advanced Energy Industries Inc
# 65      AENT     Alliance Entertainment Holding Corporation
# 66      AEON                             AEON Biopharma Inc
# 67       AEP            American Electric Power Company Inc
# 68       AES                                       AES Corp
# 69      AEVA                          Aeva Technologies Inc
# 70      AEYE                                   AudioEye Inc
# 71      AFCG                    Advanced Flower Capital Inc
# 72      AFRM                            Affirm Holdings Inc
# 73      AGAE              Allied Gaming & Entertainment Inc
# 74      AGEN                                     Agenus Inc
# 75      AGIO                      Agios Pharmaceuticals Inc
# 76       AGM             Federal Agricultural Mortgage Corp
# 77      AGNC                           AGNC Investment Corp
# 78       AGX                                     Argan, Inc
# 79      AGYS                                  Agilysys, Inc
# 80      AHCO                               AdaptHealth Corp
# 81       AHH                  Armada Hoffler Properties Inc
# 82       AHR                   American Healthcare REIT Inc
# 83       AIG               American International Group Inc
# 84       AII         American Integrity Insurance Group Inc
# 85       AIM                             AIM ImmunoTech Inc
# 86      AIOT                                 PowerFleet Inc
# 87       AIP                                    Arteris Inc
# 88       AIR                                       AAR Corp
# 89      AIRE                              reAlpha Tech Corp
# 90      AIRG                                    Airgain Inc
# 91      AIRI                           Air Industries Group
# 92      AIRJ                     AirJoule Technologies Corp
# 93      AIRO                        AIRO Group Holdings Inc
# 94      AIRS                     Airsculpt Technologies Inc
# 95      AISP                        Airship AI Holdings Inc
# 96       AIT            Applied Industrial Technologies Inc
# 97       AIV           Apartment Investment & Management Co
# 98      AIXC                         AIxCrypto Holdings Inc
# 99       AIZ                                   Assurant Inc
# 100      AJG                       Arthur J. Gallagher & Co
# 101      AKA                     a.k.a. Brands Holding Corp
# 102     AKAM                        Akamai Technologies Inc
# 103     AKBA                        Akebia Therapeutics Inc
# 104      AKR                            Acadia Realty Trust
# 105     AKTX                     Akari Therapeutics Plc ADR
# 106     ALAB                                Astera Labs Inc
# 107     ALCO                                      Alico Inc
# 108     ALDX                       Aldeyra Therapeutics Inc
# 109     ALEX                        Alexander & Baldwin Inc
# 110      ALG                                Alamo Group Inc
# 111     ALGM                       Allegro Microsystems Inc
# 112     ALGN                          Align Technology, Inc
# 113     ALGS                        Aligos Therapeutics Inc
# 114      ALH                  Alliance Laundry Holdings Inc
# 115     ALHC                       Alignment Healthcare Inc
# 116     ALIT                                     Alight Inc
# 117      ALK                           Alaska Air Group Inc
# 118     ALKT                          Alkami Technology Inc
# 119      ALL                                  Allstate Corp
# 120     ALLO                      Allogene Therapeutics Inc
# 261     ATGE                   Adtalem Global Education Inc
# 262     ATHR                            Aether Holdings Inc
# 263      ATI                                        ATI Inc
# 264     ATKR                                     Atkore Inc
# 265     ATLC                       Atlanticus Holdings Corp
# 266     ATLN                    Atlantic International Corp
# 267     ATMU              Atmus Filtration Technologies Inc
# 268     ATNI                          ATN International Inc
# 269     ATNM                   Actinium Pharmaceuticals Inc
# 270     ATOM                                    Atomera Inc
# 271     ATOS                        Atossa Therapeutics Inc
# 272      ATR                                 Aptargroup Inc
# 273     ATRA                      Atara Biotherapeutics Inc
# 274     ATRC                                   Atricure Inc
# 275     ATRO                                 Astronics Corp
# 276     ATYR                                Atyr Pharma Inc
# 277      AUB                 Atlantic Union Bankshares Corp
# 278     AUGO                              Aura Minerals Inc
# 279      AUR                          Aurora Innovation Inc
# 280     AURA                           Aura Biosciences Inc
# 281     AUUD                                     Auddia Inc
# 282     AVAH                Aveanna Healthcare Holdings Inc
# 283     AVAV                              AeroVironment Inc
# 284      AVB                      Avalonbay Communities Inc
# 285     AVBC                             Avidia Bancorp Inc
# 286     AVBH                          Avidbank Holdings Inc
# 287     AVBP                         ArriVent BioPharma Inc
# 288      AVD                         American Vanguard Corp
# 289     AVGO                                   Broadcom Inc
# 290     AVIR                       Atea Pharmaceuticals Inc
# 291     AVNT                                    Avient Corp
# 292     AVNW                             Aviat Networks Inc
# 293      AVO                            Mission Produce Inc
# 294     AVPT                                   AvePoint Inc
# 295      AVR               Anteris Technologies Global Corp
# 296     AVTX                         Avalo Therapeutics Inc
# 297     AVXL               Anavex Life Sciences Corporation
# 298      AVY                            Avery Dennison Corp
# 299      AWI                 Armstrong World Industries Inc
# 300      AWR                       American States Water Co
# 301     AWRE                                      Aware Inc
# 302      AWX                           Avalon Holdings Corp
# 303       AX                             Axos Financial Inc
# 304     AXGN                                     Axogen Inc
# 305     AXON                            Axon Enterprise Inc
# 306      AXP                            American Express Co
# 307      AXR                                     AMREP Corp
# 308     AXSM                        Axsome Therapeutics Inc
# 309     AXTA                     Axalta Coating Systems Ltd
# 310     AXTI                                        AXT Inc
# 311      AYI                                     Acuity Inc
# 312     AYTU                             Aytu BioPharma Inc
# 313      AZO                                   Autozone Inc
# 314     AZTA                                     Azenta Inc
# 315     AZTR                                     Azitra Inc
# 316      AZZ                                        AZZ Inc
# 317       BA                                      Boeing Co
# 318      BAC                           Bank Of America Corp
# 319     BAER           Bridger Aerospace Group Holdings Inc
# 320     BALL                                      Ball Corp
# 321      BAM                Brookfield Asset Management Ltd
# 322     BANC                         Banc of California Inc
# 323     BAND                                  Bandwidth Inc
# 324     BANR                                    Banner Corp
# 325     BARK                                       BARK Inc
# 326    BATRA                    Atlanta Braves Holdings Inc
# 327    BATRK                    Atlanta Braves Holdings Inc
# 328     BBAI                        BigBear.ai Holdings Inc
# 329     BBBY                          Bed Bath & Beyond Inc
# 330     BBCP                  Concrete Pumping Holdings Inc
# 331     BBDC                                Barings BDC Inc
# 332     BBGI                    Beasley Broadcast Group Inc
# 333     BBIO                           BridgeBio Pharma Inc
# 334     BBLG                            Bone Biologics Corp
# 335     BBNX                               Beta Bionics Inc
# 336     BBOT            BridgeBio Oncology Therapeutics Inc
# 337     BBSI                  Barrett Business Services Inc
# 338      BBT                          Beacon Financial Corp
# 339      BBW                      Build A Bear Workshop Inc
# 340     BBWI                          Bath & Body Works Inc
# 341       BC                                 Brunswick Corp
# 342     BCAB                                    BioAtla Inc
# 343     BCAL                             California BanCorp
# 344     BCAX                        Bicara Therapeutics Inc
# 345     BCBP                           BCB Bancorp Inc (NJ)
# 346      BCC                               Boise Cascade Co
# 347     BCDA                                  BioCardia Inc
# 348     BCIC                            BCP Investment Corp
# 349     BCML                                    BayCom Corp
# 350      BCO                                     Brink's Co
# 351     BCPC                                   Balchem Corp
# 352     BCRX                   Biocryst Pharmaceuticals Inc
# 353     BCSF             Bain Capital Specialty Finance Inc
# 354      BDC                                     Belden Inc
# 355     BDSX                                   Biodesix Inc
# 356     BDTX                 Black Diamond Therapeutics Inc
# 357      BDX                          Becton Dickinson & Co
# 358       BE                              Bloom Energy Corp
# 359     BEAM                          Beam Therapeutics Inc
# 360     BEAT                                  HeartBeam Inc
# 361     BEEM                                    Beam Global
# 362     BEEP                     Mobile Infrastructure Corp
# 363    BELFB                                   Bel Fuse Inc
# 364     BEPC                      Brookfield Renewable Corp
# 365     BFAM          Bright Horizons Family Solutions, Inc
# 366      BFC                                Bank First Corp
# 367     BFLY                          Butterfly Network Inc
# 368     BFRI                                Biofrontera Inc
# 369      BFS                              Saul Centers, Inc
# 370     BFST                  Business First Bancshares Inc
# 371       BG                                Bunge Global SA
# 372      BGC                                  BGC Group Inc
# 373     BGSF                                       BGSF Inc
# 374      BHB                      Bar Harbor Bankshares Inc
# 375      BHE                      Benchmark Electronics Inc
# 376      BHM                       Bluerock Homes Trust Inc
# 377     BHRB        Burke & Herbert Financial Services Corp
# 378     BHVN                                   Biohaven Ltd
# 379     BIAF                   BioAffinity Technologies Inc
# 380     BIIB                                     Biogen Inc
# 381     BILL                              BILL Holdings Inc
# 382      BIO                       Bio-Rad Laboratories Inc
# 383     BIRD                                   Allbirds Inc
# 384     BIVI                                     BioVie Inc
# 385       BJ               BJ's Wholesale Club Holdings Inc
# 386       BK                   Bank Of New York Mellon Corp
# 387      BKH                        Black Hills Corporation
# 388     BKKT                             Bakkt Holdings Inc
# 389     BKNG                           Booking Holdings Inc
# 390      BKR                                Baker Hughes Co
# 391     BKSY                        BlackSky Technology Inc
# 392     BKTI                           BK Technologies Corp
# 393      BKV                                       BKV Corp
# 394     BKYI                      Bio-Key International Inc
# 395     BLBD                                 Blue Bird Corp
# 396     BLBX                             Blackboxstocks Inc
# 397      BLD                                  TopBuild Corp
# 398     BLDR                       Builders Firstsource Inc
# 399     BLFS                          Biolife Solutions Inc
# 400     BLIN                         Bridgeline Digital Inc
# 401      BLK                                  Blackrock Inc
# 402     BLND                                 Blend Labs Inc
# 403     BLNE                           Beeline Holdings Inc
# 404     BLTE                             Belite Bio Inc ADR
# 405     BLZE                                  Backblaze Inc
# 406     BMEA                              Biomea Fusion Inc
# 407      BMI                               Badger Meter Inc
# 408     BMNR             BitMine Immersion Technologies Inc
# 409     BMRA                                  Biomerica Inc
# 410     BMRC                          Bank of Marin Bancorp
# 411     BMRN                    Biomarin Pharmaceutical Inc
# 412     BNAI                   Brand Engagement Network Inc
# 413      BNC                             CEA Industries Inc
# 414     BNGO                           Bionano Genomics Inc
# 415     BNKK                                       Bonk Inc
# 416      BNL                       Broadstone Net Lease Inc
# 417     BNTC                          Benitec Biopharma Inc
# 418     BNZI                       Banzai International Inc
# 419      BOC                              Boston Omaha Corp
# 420     BODI                          Beachbody Company Inc
# 421     BOKF                             BOK Financial Corp
# 422     BOLT                       Bolt Biotherapeutics Inc
# 423     BOOM                                 DMC Global Inc
# 424     BOOT                         Boot Barn Holdings Inc
# 425      BOW                 Bowhead Specialty Holdings Inc
# 426      BOX                                        Box Inc
# 427     BPOP                                    Popular Inc
# 428     BPRN                          Princeton Bancorp Inc
# 429       BR            Broadridge Financial Solutions, Inc
# 430     BRBR                            Bellring Brands Inc
# 431      BRC                                     Brady Corp
# 432     BRCB                      Black Rock Coffee Bar Inc
# 433     BRCC                                        BRC Inc
# 434     BRFH                        Barfresh Food Group Inc
# 435     BRIA                                    BrilliA Inc
# 436     BRKR                                    Bruker Corp
# 437     BRLT                      Brilliant Earth Group Inc
# 438     BROS                                 Dutch Bros Inc
# 439     BRSP                        BrightSpire Capital Inc
# 440      BRT                            BRT Apartments Corp
# 441     BRTX                   BioRestorative Therapies Inc
# 442      BRX                     Brixmor Property Group Inc
# 443      BRY                                     Berry Corp
# 444     BRZE                                      Braze Inc
# 445      BSM                       Black Stone Minerals L.P
# 446     BSVN                                     Bank7 Corp
# 447      BSX                         Boston Scientific Corp
# 448      BSY                            Bentley Systems Inc
# 449     BTAI                       BioXcel Therapeutics Inc
# 450     BTBT                                Bit Digital Inc
# 451     BTCS                                       BTCS Inc
# 452      BTM                              Bitcoin Depot Inc
# 453     BTMD                                     biote Corp
# 454     BTSG               BrightSpring Health Services Inc
# 455      BTU                            Peabody Energy Corp
# 456     BULL                                    Webull Corp
# 457     BURL                          Burlington Stores Inc
# 458     BUSE                               First Busey Corp
# 459       BV                        BrightView Holdings Inc
# 460      BVS                                  Bioventus Inc
# 461       BW               Babcock & Wilcox Enterprises Inc
# 462      BWA                                 BorgWarner Inc
# 463      BWB                     Bridgewater Bancshares Inc
# 464     BWEN                                  Broadwind Inc
# 465     BWFG                   Bankwell Financial Group Inc
# 466     BWIN                The Baldwin Insurance Group Inc
# 467     BWMN                    Bowman Consulting Group Ltd
# 468     BWXT                           BWX Technologies Inc
# 469       BX                                 Blackstone Inc
# 470      BXC                             Bluelinx Hldgs Inc
# 471     BXMT                  Blackstone Mortgage Trust Inc
# 472      BXP                                        BXP Inc
# 473     BXSL                Blackstone Secured Lending Fund
# 474       BY                             Byline Bancorp Inc
# 475      BYD                               Boyd Gaming Corp
# 476     BYRN                         Byrna Technologies Inc
# 477     BYSI                               BeyondSpring Inc
# 478     BZAI                            Blaize Holdings Inc
# 479      BZH                           Beazer Homes USA Inc
# 480        C                                  Citigroup Inc
# 481     CABA                              Cabaletta Bio Inc
# 482      CAC                           Camden National Corp
# 483     CACI                         Caci International Inc
# 484     CADE                                   Cadence Bank
# 485     CADL                        Candel Therapeutics Inc
# 486      CAH                           Cardinal Health, Inc
# 487      CAI                        Caris Life Sciences Inc
# 488      CAL                                    Caleres Inc
# 489     CALC                                CalciMedica Inc
# 490     CALX                                      Calix Inc
# 491     CAMP                        CAMP4 Therapeutics Corp
# 492     CAPL                       CrossAmerica Partners LP
# 493     CAPR                      Capricor Therapeutics Inc
# 494     CAPS                          Capstone Holding Corp
# 495     CARE                          Carter Bankshares Inc
# 496     CARG                                   CarGurus Inc
# 497     CARL                                   Carlsmed Inc
# 498     CARR                            Carrier Global Corp
# 499     CARS                                       Cars.com
# 500     CART                                  Maplebear Inc
# 501     CASS                   Cass Information Systems Inc
# 502     CASY                    Casey's General Stores, Inc
# 503      CAT                                Caterpillar Inc
# 504     CATX                   Perspective Therapeutics Inc
# 505     CAVA                                 Cava Group Inc
# 506     CBAN                           Colony Bankcorp, Inc
# 507     CBFV                      CB Financial Services Inc
# 508     CBIO                         Crescent Biopharma Inc
# 509      CBK                       Commercial Bancgroup Inc
# 510      CBL                CBL& Associates Properties, Inc
# 511     CBLL                                   Ceribell Inc
# 512     CBNA                       Chain Bridge Bancorp Inc
# 513     CBNK                            Capital Bancorp Inc
# 514     CBRE                                 CBRE Group Inc
# 515      CBU                 Community Financial System Inc
# 516     CBUS                                      Cibus Inc
# 517      CBZ                                       Cbiz Inc
# 518       CC                               Chemours Company
# 519     CCAP                       Crescent Capital BDC Inc
# 520      CCB                         Coastal Financial Corp
# 521     CCBG                   Capital City Bank Group, Inc
# 522      CCC         CCC Intelligent Solutions Holdings Inc
# 523     CCCC                            C4 Therapeutics Inc
# 524     CCEL                   Cryo-Cell International, Inc
# 525      CCI                               Crown Castle Inc
# 526     CCIF                     Carlyle Credit Income Fund
# 527      CCK                            Crown Holdings, Inc
# 528      CCL                                  Carnival Corp
# 529     CCLD                                  CareCloud Inc
# 530     CCNE                        CNB Financial Corp (PA)
# 531     CCOI             Cogent Communications Holdings Inc
# 532      CCS                        Century Communities Inc
# 533     CCSI                  Consensus Cloud Solutions Inc
# 534      CDE                               Coeur Mining Inc
# 535     CDIO                Cardio Diagnostics Holdings Inc
# 536     CDNA                                     Caredx Inc
# 537     CDNS                    Cadence Design Systems, Inc
# 538      CDP                        COPT Defense Properties
# 539     CDRE                             Cadre Holdings Inc
# 540     CDTX                        Cidara Therapeutics Inc
# 541      CDW                                       CDW Corp
# 542     CDXS                                    Codexis Inc
# 543     CDZI                                      Cadiz Inc
# 544       CE                                  Celanese Corp
# 545     CECO                        Ceco Environmental Corp
# 546      CEG               Constellation Energy Corporation
# 547     CELC                                   Celcuity Inc
# 548     CELH                           Celsius Holdings Inc
# 549     CELU                                 Celularity Inc
# 550     CELZ       Creative Medical Technology Holdings Inc
# 551     CENT                        Central Garden & Pet Co
# 552    CENTA                        Central Garden & Pet Co
# 553     CENX                            Century Aluminum Co
# 554     CERS                                     Cerus Corp
# 555     CERT                                    Certara Inc
# 556     CETX                                    Cemtrex Inc
# 557     CEVA                                       Ceva Inc
# 558     CFBK                              CF Bankshares Inc
# 559      CFG                   Citizens Financial Group Inc
# 560     CFLT                                  Confluent Inc
# 561       CG                              Carlyle Group Inc
# 562     CGEM                      Cullinan Therapeutics Inc
# 563     CGNX                                    Cognex Corp
# 564     CGON                                Cg Oncology Inc
# 565     CGTX                     Cognition Therapeutics Inc
# 566     CHCT                 Community Healthcare Trust Inc
# 567     CHDN                           Churchill Downs, Inc
# 568      CHE                                    Chemed Corp
# 569     CHEF                           Chefs' Warehouse Inc
# 570     CHMG                         Chemung Financial Corp
# 571     CHMI    Cherry Hill Mortgage Investment Corporation
# 572     CHRD                              Chord Energy Corp
# 573     CHRS                           Coherus Oncology Inc
# 574     CHRW                   C.H. Robinson Worldwide, Inc
# 575     CHWY                                      Chewy Inc
# 576     CHYM                            Chime Financial Inc
# 577       CI                                    Cigna Group
# 578      CIA                                  Citizens, Inc
# 579     CIEN                                     CIENA Corp
# 580     CIFR                              Cipher Mining Inc
# 581      CIM                        Chimera Investment Corp
# 582     CINF                      Cincinnati Financial Corp
# 583     CING                                  Cingulate Inc
# 584     CISO                                CISO Global Inc
# 585     CIVB                         Civista Bancshares Inc
# 586       CL                           Colgate-Palmolive Co
# 587     CLAR                                    Clarus Corp
# 588     CLBK                        Columbia Financial, Inc
# 589     CLDI                     Calidi Biotherapeutics Inc
# 590     CLDT                          Chatham Lodging Trust
# 591     CLDX                       Celldex Therapeutics Inc
# 592     CLFD                                 Clearfield Inc
# 593      CLH                             Clean Harbors, Inc
# 594     CLIR                    ClearSign Technologies Corp
# 595     CLMB                     Climb Global Solutions Inc
# 596     CLMT                                    Calumet Inc
# 597     CLNE                        Clean Energy Fuels Corp
# 598     CLNN                                      Clene Inc
# 599     CLOV                 Clover Health Investments Corp
# 600     CLPR                             Clipper Realty Inc
# 601     CLPT                           ClearPoint Neuro Inc
# 602     CLRB                      Cellectar Biosciences Inc
# 603     CLRO                                   ClearOne Inc
# 604     CLSD                       Clearside Biomedical Inc
# 605     CLSK                                 Cleanspark Inc
# 606      CLW                          Clearwater Paper Corp
# 607     CLYM                                  Climb Bio Inc
# 608       CM             Canadian Imperial Bank Of Commerce
# 609     CMBM                          Cambium Networks Corp
# 610      CMC                           Commercial Metals Co
# 611     CMCO                         Columbus Mckinnon Corp
# 612    CMCSA                                   Comcast Corp
# 613      CMG                         Chipotle Mexican Grill
# 614      CMI                                    Cummins Inc
# 615     CMPO                                CompoSecure Inc
# 616     CMPX                       Compass Therapeutics Inc
# 617      CMS                         CMS Energy Corporation
# 618      CMT                      Core Molding Technologies
# 619     CMTL                Comtech Telecommunications Corp
# 620     CNDT                                   Conduent Inc
# 621      CNK                          Cinemark Holdings Inc
# 622      CNM                                Core & Main Inc
# 623     CNNE                            Cannae Holdings Inc
# 624     CNOB                         ConnectOne Bancorp Inc
# 625      CNP                         Centerpoint Energy Inc
# 626      CNR                     Core Natural Resources Inc
# 627      CNS                             Cohen & Steers Inc
# 628     CNSP                        Cns Pharmaceuticals Inc
# 629     CNTB                 Connect Biopharma Holdings Ltd
# 630     CNTX                       Context Therapeutics Inc
# 631     CNTY                            Century Casinos Inc
# 632     CNVS                                 Cineverse Corp
# 633     CNXC                                Concentrix Corp
# 634     COCH                              Envoy Medical Inc
# 635     COCO                          Vita Coco Company Inc
# 636     COCP                           Cocrystal Pharma Inc
# 637     CODA                         Coda Octopus Group Inc
# 638     CODX                             Co-Diagnostics Inc
# 639     COEP              Coeptis Therapeutics Holdings Inc
# 640      COF                     Capital One Financial Corp
# 641     COFS              Choiceone Financial Services, Inc
# 642     COGT                         Cogent Biosciences Inc
# 643     COHR                                  Coherent Corp
# 644     COHU                                      Cohu, Inc
# 645     COIN                            Coinbase Global Inc
# 646     COLB                   Columbia Banking System, Inc
# 647     COLD                     Americold Realty Trust Inc
# 648     COLL                   Collegium Pharmaceutical Inc
# 649     COMM                  CommScope Holding Company Inc
# 650     COMP                                    Compass Inc
# 651      CON            Concentra Group Holdings Parent Inc
# 652      COO                          Cooper Companies, Inc
# 653      COP                                Conoco Phillips
# 654      COR                                    Cencora Inc
# 655     CORT                       Corcept Therapeutics Inc
# 656     CORZ                            Core Scientific Inc
# 657     COSO                    CoastalSouth Bancshares Inc
# 658     COST                          Costco Wholesale Corp
# 659     COUR                                   Coursera Inc
# 660     COYA                          Coya Therapeutics Inc
# 661     CPAY                                     Corpay Inc
# 662      CPF                 Central Pacific Financial Corp
# 663     CPIX                 Cumberland Pharmaceuticals Inc
# 664      CPK                      Chesapeake Utilities Corp
# 665     CPNG                                    Coupang Inc
# 666     CPRT                                    Copart, Inc
# 667     CPRX                   Catalyst Pharmaceuticals Inc
# 668      CPS                   Cooper-Standard Holdings Inc
# 669     CPSH                   CPS Technologies Corporation
# 670     CPSS                Consumer Portfolio Service, Inc
# 671      CPT                          Camden Property Trust
# 672       CR                                       Crane Co
# 673     CRAI                          CRA International Inc
# 674     CRBG                       Corebridge Financial Inc
# 675     CRBP            Corbus Pharmaceuticals Holdings Inc
# 676     CRBU                        Caribou Biosciences Inc
# 677      CRC               California Resources Corporation
# 678     CRCL                      Circle Internet Group Inc
# 679    CRD-A                                  Crawford & Co
# 680    CRD-B                                  Crawford & Co
# 681     CRDF                           Cardiff Oncology Inc
# 682     CREX                         Creative Realities Inc
# 683     CRGY                             Crescent Energy Co
# 684      CRH                                        CRH Plc
# 685     CRIS                                      Curis Inc
# 686      CRL   Charles River Laboratories International Inc
# 687      CRM                                 Salesforce Inc
# 688     CRMD                                   CorMedix Inc
# 689     CRMT                         Americas Car Mart, Inc
# 690     CRNX                  Crinetics Pharmaceuticals Inc
# 691     CROX                                      Crocs Inc
# 692      CRS                      Carpenter Technology Corp
# 693     CRSR                             Corsair Gaming Inc
# 694     CRUS                              Cirrus Logic, Inc
# 695     CRVO                                   CervoMed Inc
# 696     CRVS                     Corvus Pharmaceuticals Inc
# 697     CRWD                       Crowdstrike Holdings Inc
# 698     CRWS                              Crown Crafts, Inc
# 699     CRWV                                  CoreWeave Inc
# 700     CSAI                            Cloudastructure Inc
# 701     CSBR                         Champions Oncology Inc
# 702     CSCO                             Cisco Systems, Inc
# 703     CSGP                              Costar Group, Inc
# 704      CSL                         Carlisle Companies Inc
# 705      CSR                                    Centerspace
# 706     CSTL                         Castle Biosciences Inc
# 707      CSV                         Carriage Services, Inc
# 708     CSWC                         Capital Southwest Corp
# 709      CSX                                       CSX Corp
# 710     CTAS                             Cintas Corporation
# 711     CTBI                   Community Trust Bancorp, Inc
# 712     CTEV                                  Claritev Corp
# 713     CTGO                               Contango Ore Inc
# 714     CTKB                          Cytek BioSciences Inc
# 715      CTM                                  Castellum Inc
# 716     CTMX                        CytomX Therapeutics Inc
# 717     CTNM                     Contineum Therapeutics Inc
# 718     CTNT           Cheetah Net Supply Chain Service Inc
# 719      CTO                          CTO Realty Growth Inc
# 720     CTOR                            Citius Oncology Inc
# 721     CTOS                    Custom Truck One Source Inc
# 722     CTRA                             Coterra Energy Inc
# 723     CTRE                             CareTrust REIT Inc
# 724     CTRN                                Citi Trends Inc
# 725     CTSH            Cognizant Technology Solutions Corp
# 726     CTSO                              Cytosorbents Corp
# 727     CTVA                                    Corteva Inc
# 728     CTXR                     Citius Pharmaceuticals Inc
# 729     CUBE                                      CubeSmart
# 730     CUBI                          Customers Bancorp Inc
# 731      CUE                              Cue Biopharma Inc
# 732     CULP                                       Culp Inc
# 733     CURB                       Curbline Properties Corp
# 734     CURI                            CuriosityStream Inc
# 735      CUZ                         Cousins Properties Inc
# 736       CV                                CapsoVision Inc
# 737     CVBF                             CVB Financial Corp
# 738     CVCO                           Cavco Industries Inc
# 739     CVEO                                     Civeo Corp
# 740     CVGI                   Commercial Vehicle Group Inc
# 741     CVGW                            Calavo Growers, Inc
# 742     CVKD                      Cadrenal Therapeutics Inc
# 743     CVLG                   Covenant Logistics Group Inc
# 744     CVLT                          Commvault Systems Inc
# 745      CVM                                   Cel-Sci Corp
# 746     CVNA                                     Carvana Co
# 747     CVRX                                       CVRx Inc
# 748      CVS                                CVS Health Corp
# 749      CVV                             CVD Equipment Corp
# 750      CVX                                   Chevron Corp
# 751       CW                            Curtiss-Wright Corp
# 752     CWAN              Clearwater Analytics Holdings Inc
# 753     CWBC                      Community West Bancshares
# 754      CWD                                 CaliberCos Inc
# 755     CWEN                            Clearway Energy Inc
# 756   CWEN-A                            Clearway Energy Inc
# 757      CWH                     Camping World Holdings Inc
# ...
# 1710               Financial    12.20            USA
# 1711               Financial     9.94            USA
# 1969              Technology    80.33            USA
# 1970              Healthcare     3.01            USA
# 1971              Technology     1.06            USA
# 1972              Technology   118.93            USA
# 1973      Consumer Defensive   123.11            USA
# 1974              Healthcare    28.32            USA
# 1975             Real Estate    20.84            USA
# 1976              Healthcare     4.56            USA
# 1977  Communication Services    71.62            USA
# 1978              Healthcare    36.51            USA
# 1979              Healthcare    18.73            USA
# 1980              Healthcare     9.69            USA
# 1981         Basic Materials     2.06            USA
# 1982               Financial    62.03            USA
# 1983              Technology    50.24            USA
# 1984               Financial    21.73            USA
# 1985              Healthcare     2.78            USA
# 1986              Technology     7.90            USA
# 1987       Consumer Cyclical    12.15            USA
# 1988  Communication Services     0.86            USA
# 1989               Financial    44.55            USA
# 1990             Real Estate     2.25            USA
# 1991              Technology   143.16            USA
# 1992              Technology    11.24            USA
# 1993               Utilities     2.41            USA
# 1994               Financial    13.45            USA
# 1995              Healthcare    31.10            USA
# 1996               Financial     9.90            USA
# 1997              Healthcare     1.36            USA
# 1998               Financial     5.17            USA
# 1999              Healthcare    15.27            USA

# %%
import pandas as pd
from finvizfinance.screener.overview import Overview

def get_filtered_picks(countries=['USA'], limit_per_country=5000):
    all_stocks = []
    
    for country in countries:
        print(f"Fetching candidates for: {country}...")
        
        try:
            foverview = Overview()
            
            # --- STEP 1: Broaden the initial search ---
            filters_dict = {
                'Analyst Recom.': 'Buy or better',
                'Country': country
            }
            foverview.set_filter(filters_dict=filters_dict)
            
            # Get results
            df_results = foverview.screener_view()
            
            if not df_results.empty:
                df_results['Source_Country'] = country
                all_stocks.append(df_results)
            else:
                print(f"   No stocks found for {country}.")
                
        except Exception as e:
            print(f"   Error fetching {country}: {e}")

    if not all_stocks:
        print("\nNo stocks found from any country.")
        return pd.DataFrame()

    # Combine all results
    combined_df = pd.concat(all_stocks, ignore_index=True)
    
    # --- STEP 2: The "Option 2" Pandas Filter ---
    cols = combined_df.columns.tolist()
    recom_col = 'Recom' if 'Recom' in cols else 'Analyst Recom'
    
    if recom_col in cols:
        # Convert column to numbers
        combined_df[recom_col] = pd.to_numeric(combined_df[recom_col], errors='coerce')
        
        # Filter: keep anything <= 1.5 (Strong Buys)
        print(f"Filtering out 'Hold' or worse (Rating > 1.5)...")
        combined_df = combined_df[combined_df[recom_col] < 1.5]
        
        # Sort by best rating
        combined_df = combined_df.sort_values(by=recom_col, ascending=True)

    # Clean up columns
    desired_cols = ['Ticker', 'Company', 'Sector', 'Price', 'Source_Country', recom_col]
    final_cols = [c for c in desired_cols if c in combined_df.columns]
    
    return combined_df[final_cols].head(limit_per_country * len(countries))

# --- Usage ---
top_picks = get_filtered_picks(['USA'])

if not top_picks.empty:
    # Ensure Price is numeric (Crucial for sorting in Data Viewer)
    top_picks['Price'] = pd.to_numeric(top_picks['Price'], errors='coerce')

    print(f"\nSuccess! Found {len(top_picks)} candidates.")
    print("Variable 'top_picks' is ready for the Data Viewer.")

else:
    print("DataFrame is empty.")
# Out:
# Fetching candidates for: USA...
# [Info] loading page [################--------------] 81/150

# %%
if not top_picks.empty:
    # Ensure the 'Price' column is numeric (removes any potential formatting errors)
    top_picks['Price'] = pd.to_numeric(top_picks['Price'], errors='coerce')

    # Filter for stocks with Price < 30
    cheap_picks = top_picks[top_picks['Price'] < 30]

    print(f"\nFound {len(cheap_picks)} stocks under $30.")
    print(cheap_picks)
else:
    print("DataFrame is empty.")

# %%
import yfinance as yf
import time

# Loop through EVERY symbol in the list (removed the [:3])
for symbol in ticker_list:
    
    # 1. Fetch data
    stock = yf.Ticker(symbol)
    print(f"\n--- Checking {symbol} ---")
    
    try:
        # 2. Get the upgrades/downgrades
        upgrades = stock.upgrades_downgrades
        
        if not upgrades.empty:
            # Filter for 2025 actions using the .index fix
            recent = upgrades[upgrades.index >= '2025-11-01']
            
            if not recent.empty:
                print(recent)
            else:
                print(f"No actions for {symbol} in 2025.")
        else:
            print(f"No analyst history found for {symbol}.")
            
    except Exception as e:
        print(f"Error fetching {symbol}: {e}")

    # 3. CRITICAL: Sleep for 1 second to avoid getting banned
    time.sleep(1)
# Out:
# --- Checking A ---
#                                   Firm       ToGrade     FromGrade Action  \
# GradeDate
# 2025-11-25 19:04:11          Citigroup           Buy           Buy   main
# 2025-11-25 17:52:33                UBS           Buy           Buy   main
# 2025-11-25 15:39:43        Wells Fargo    Overweight    Overweight   main
# 2025-11-25 15:10:42          JP Morgan    Overweight    Overweight   main
# 2025-11-25 14:42:29           Barclays  Equal-Weight  Equal-Weight   main
# 2025-11-25 13:14:47              Baird    Outperform    Outperform   main
# 2025-11-25 12:05:56  B of A Securities       Neutral       Neutral   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-25 19:04:11            Raises               185.0             165.0
# 2025-11-25 17:52:33            Raises               180.0             170.0
# 2025-11-25 15:39:43            Raises               175.0             150.0
# 2025-11-25 15:10:42            Raises               180.0             165.0
# 2025-11-25 14:42:29            Raises               165.0             145.0
# 2025-11-25 13:14:47            Raises               165.0             142.0
# 2025-11-25 12:05:56            Raises               165.0             150.0
#
# --- Checking AA ---
# No actions for AA in 2025.
#
# --- Checking AAL ---
# No actions for AAL in 2025.
#
# --- Checking AAOI ---
#                                           Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-17 17:10:25  Northland Capital Markets  Outperform  Outperform   main
# 2025-11-10 10:59:52        B. Riley Securities        Sell     Neutral   down
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-17 17:10:25            Raises                35.0              30.0
# 2025-11-10 10:59:52         Maintains                15.0              15.0
#
# --- Checking AAON ---
# No actions for AAON in 2025.
#
# --- Checking AAPL ---
#                            Firm  ToGrade FromGrade Action priceTargetAction  \
# GradeDate
# 2025-11-04 13:18:21  Rosenblatt  Neutral   Neutral   main         Maintains
#
#                      currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-04 13:18:21               250.0             250.0
#
# --- Checking AARD ---
#                             Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-14 15:33:04  RBC Capital  Outperform  Outperform   main
# 2025-11-07 11:26:27         BTIG         Buy               init
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-14 15:33:04            Lowers                18.0              19.0
# 2025-11-07 11:26:27         Announces                26.0               0.0
#
# --- Checking ABAT ---
# No actions for ABAT in 2025.
#
# --- Checking ABBV ---
#                               Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-07 16:11:32            UBS     Neutral     Neutral   main
# 2025-11-05 15:40:43  Piper Sandler  Overweight  Overweight   reit
# 2025-11-03 20:05:39      Citigroup     Neutral     Neutral   main
# 2025-11-03 14:38:53      JP Morgan  Overweight  Overweight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-07 16:11:32            Raises               220.0             195.0
# 2025-11-05 15:40:43            Raises               289.0             284.0
# 2025-11-03 20:05:39            Lowers               235.0             240.0
# 2025-11-03 14:38:53            Raises               260.0             250.0
#
# --- Checking ABCB ---
#                                   Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-25 18:02:56  Truist Securities    Hold             init
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-25 18:02:56         Announces                80.0               0.0
#
# --- Checking ABEO ---
# No actions for ABEO in 2025.
#
# --- Checking ABL ---
# No actions for ABL in 2025.
#
# --- Checking ABM ---
# No actions for ABM in 2025.
#
# --- Checking ABOS ---
#                                   Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-18 17:57:40  B of A Securities     Buy       Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-18 17:57:40            Lowers                 8.0               9.0
#
# --- Checking ABSI ---
#                         Firm ToGrade FromGrade Action priceTargetAction  \
# GradeDate
# 2025-11-13 10:45:33  Needham     Buy       Buy   main            Lowers
#
#                      currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-13 10:45:33                 7.0               8.0
#
# --- Checking ABT ---
#                      Firm ToGrade FromGrade Action priceTargetAction  \
# GradeDate
# 2025-11-20 10:14:38  BTIG     Buy       Buy   reit         Maintains
#
#                      currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-20 10:14:38               145.0             145.0
#
# --- Checking ABUS ---
#                                 Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-14 20:55:38  Chardan Capital     Buy       Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-14 20:55:38         Maintains                 5.0               5.0
#
# --- Checking ACA ---
#                          Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-03 14:21:10  Barclays  Overweight  Overweight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-03 14:21:10            Raises               115.0             106.0
#
# --- Checking ACAD ---
#                             Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-17 17:23:03    JP Morgan  Overweight  Overweight   main
# 2025-11-06 15:34:08  RBC Capital  Outperform  Outperform   main
# 2025-11-06 10:05:45      Needham         Buy         Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-17 17:23:03            Lowers                31.0              33.0
# 2025-11-06 15:34:08            Lowers                32.0              34.0
# 2025-11-06 10:05:45            Raises                29.0              28.0
#
# --- Checking ACCO ---
# No actions for ACCO in 2025.
#
# --- Checking ACCS ---
# No actions for ACCS in 2025.
#
# --- Checking ACEL ---
#                           Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-05 20:55:58  Macquarie  Outperform  Outperform   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-05 20:55:58         Maintains                16.0              16.0
#
# --- Checking ACET ---
#                                     Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-07 12:36:31  HC Wainwright & Co.     Buy       Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-07 12:36:31            Raises                 9.0               4.0
# HTTP Error 404:
# --- Checking ACFN ---
# No analyst history found for ACFN.
#
# --- Checking ACHC ---
#                                   Firm       ToGrade     FromGrade Action  \
# GradeDate
# 2025-11-18 15:00:16            Keybanc    Overweight    Overweight   main
# 2025-11-12 14:19:42        RBC Capital    Outperform    Outperform   main
# 2025-11-10 14:53:42         Guggenheim           Buy           Buy   main
# 2025-11-07 18:01:18                UBS           Buy           Buy   main
# 2025-11-07 16:07:33  Cantor Fitzgerald       Neutral       Neutral   main
# 2025-11-06 14:21:41           Barclays  Equal-Weight  Equal-Weight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-18 15:00:16            Lowers                30.0              35.0
# 2025-11-12 14:19:42            Lowers                22.0              28.0
# 2025-11-10 14:53:42            Lowers                27.0              29.0
# 2025-11-07 18:01:18            Lowers                28.0              31.0
# 2025-11-07 16:07:33            Lowers                22.0              25.0
# 2025-11-06 14:21:41            Lowers                17.0              20.0
#
# --- Checking ACHR ---
#                                   Firm  ToGrade FromGrade Action  \
# GradeDate
# 2025-11-21 18:22:14  Canaccord Genuity      Buy       Buy   main
# 2025-11-11 18:03:49  Canaccord Genuity      Buy       Buy   main
# 2025-11-07 20:12:15          JP Morgan  Neutral   Neutral   main
# 2025-11-07 11:20:09            Needham      Buy       Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-21 18:22:14            Raises                13.0              12.0
# 2025-11-11 18:03:49            Lowers                12.0              13.0
# 2025-11-07 20:12:15            Lowers                 8.0              10.0
# 2025-11-07 11:20:09            Lowers                10.0              13.0
#
# --- Checking ACI ---
#                                    Firm  ToGrade FromGrade Action  \
# GradeDate
# 2025-11-11 14:18:39  Evercore ISI Group  In-Line   In-Line   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-11 14:18:39            Lowers                21.0              22.0
#
# --- Checking ACIC ---
# No actions for ACIC in 2025.
#
# --- Checking ACIW ---
# No actions for ACIW in 2025.
#
# --- Checking ACLS ---
#                                     Firm  ToGrade FromGrade Action  \
# GradeDate
# 2025-11-05 17:11:37  B. Riley Securities  Neutral   Neutral   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-05 17:11:37            Lowers                84.0              85.0
#
# --- Checking ACLX ---
#                                   Firm       ToGrade FromGrade Action  \
# GradeDate
# 2025-11-18 17:16:34     Wolfe Research  Peer Perform             init
# 2025-11-03 13:24:07  Canaccord Genuity           Buy       Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-18 17:16:34                                   0.0               0.0
# 2025-11-03 13:24:07            Raises               130.0             121.0
#
# --- Checking ACM ---
#                                   Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-21 18:01:56  Truist Securities         Buy         Buy   main
# 2025-11-21 11:32:45              Baird     Neutral  Outperform   down
# 2025-11-20 19:14:39           Barclays  Overweight  Overweight   main
# 2025-11-20 15:03:29        RBC Capital  Outperform  Outperform   main
# 2025-11-20 14:18:55     Argus Research         Buy         Buy   main
# 2025-11-19 16:47:01          Citigroup         Buy         Buy   main
# 2025-11-19 15:07:26                UBS         Buy         Buy   main
# 2025-11-19 12:27:19              Baird  Outperform  Outperform   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-21 18:01:56            Raises               148.0             146.0
# 2025-11-21 11:32:45         Maintains               143.0             143.0
# 2025-11-20 19:14:39            Lowers               135.0             145.0
# 2025-11-20 15:03:29            Lowers               139.0             142.0
# 2025-11-20 14:18:55            Lowers               135.0             155.0
# 2025-11-19 16:47:01            Raises               152.0             150.0
# 2025-11-19 15:07:26            Lowers               148.0             153.0
# 2025-11-19 12:27:19            Lowers               143.0             144.0
#
# --- Checking ACMR ---
# No actions for ACMR in 2025.
#
# --- Checking ACNB ---
# No actions for ACNB in 2025.
#
# --- Checking ACNT ---
# No actions for ACNT in 2025.
#
# --- Checking ACOG ---
# No actions for ACOG in 2025.
#
# --- Checking ACON ---
#                                    Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-20 10:39:43  Ascendiant Capital     Buy       Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-20 10:39:43            Raises                23.0              22.0
#
# --- Checking ACR ---
# No actions for ACR in 2025.
#
# --- Checking ACRS ---
# No actions for ACRS in 2025.
#
# --- Checking ACRV ---
#                                     Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-25 11:44:27  HC Wainwright & Co.     Buy       Buy   reit
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-25 11:44:27         Maintains                19.0              19.0
#
# --- Checking ACT ---
#                           Firm  ToGrade FromGrade Action priceTargetAction  \
# GradeDate
# 2025-11-07 20:17:35  JP Morgan  Neutral   Neutral   main            Lowers
#
#                      currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-07 20:17:35                39.0              40.0
#
# --- Checking ACTG ---
# No actions for ACTG in 2025.
#
# --- Checking ACTU ---
#                                     Firm ToGrade FromGrade Action  \
# GradeDate
# 2025-11-19 11:30:04  HC Wainwright & Co.     Buy       Buy   reit
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-19 11:30:04         Maintains                20.0              20.0
#
# --- Checking ACU ---
# No actions for ACU in 2025.
#
# --- Checking ACVA ---
#                                     Firm         ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-21 20:10:56            Citigroup             Buy         Buy   main
# 2025-11-12 15:28:13             Barclays    Equal-Weight               init
# 2025-11-07 17:14:54        Goldman Sachs             Buy         Buy   main
# 2025-11-06 22:05:36            JP Morgan      Overweight  Overweight   main
# 2025-11-06 20:21:59  Barrington Research  Market Perform  Outperform   down
# 2025-11-06 11:55:17    B of A Securities    Underperform         Buy   down
# 2025-11-06 11:02:21              Needham             Buy         Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-21 20:10:56            Lowers                13.0              17.0
# 2025-11-12 15:28:13         Announces                 6.0               0.0
# 2025-11-07 17:14:54            Lowers                13.0              21.0
# 2025-11-06 22:05:36            Lowers                11.0              18.0
# 2025-11-06 20:21:59                                   0.0               0.0
# 2025-11-06 11:55:17            Lowers                 6.0              16.5
# 2025-11-06 11:02:21            Lowers                 9.0              14.0
#
# --- Checking ACXP ---
# No actions for ACXP in 2025.
#
# --- Checking AD ---
#                             Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-25 14:53:19  RBC Capital  Outperform  Outperform   main
# 2025-11-06 15:59:13  Wells Fargo  Overweight  Overweight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-25 14:53:19            Lowers                56.0              62.0
# 2025-11-06 15:59:13            Lowers                62.0              82.0
#
# --- Checking ADAM ---
# No actions for ADAM in 2025.
#
# --- Checking ADBE ---
#                             Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-20 17:50:51  DA Davidson         Buy         Buy   main
# 2025-11-20 16:35:52       Mizuho  Outperform  Outperform   main
# 2025-11-20 15:45:39  Wells Fargo  Overweight  Overweight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-20 17:50:51         Maintains               500.0             500.0
# 2025-11-20 16:35:52            Lowers               390.0             410.0
# 2025-11-20 15:45:39            Lowers               420.0             470.0
#
# --- Checking ADC ---
#                             Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-11-25 17:09:17  Wells Fargo  Overweight  Overweight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-25 17:09:17            Raises                83.0              81.0
#
# --- Checking ADEA ---
#                               Firm ToGrade FromGrade Action priceTargetAction  \
# GradeDate
# 2025-11-04 17:38:22  BWS Financial     Buy       Buy   main         Maintains
# 2025-11-04 13:07:13     Rosenblatt     Buy       Buy   main         Maintains
#
#                      currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-04 17:38:22                18.0              18.0
# 2025-11-04 13:07:13                17.0              17.0
#
# --- Checking ADI ---
#                                    Firm       ToGrade     FromGrade Action  \
# GradeDate
# 2025-11-26 18:01:29   Truist Securities          Hold          Hold   main
# 2025-11-26 17:19:29               Baird    Outperform    Outperform   main
# 2025-11-26 16:15:50           JP Morgan    Overweight    Overweight   main
# 2025-11-26 15:49:01         Wells Fargo  Equal-Weight  Equal-Weight   main
# 2025-11-26 14:51:03      Morgan Stanley    Overweight    Overweight   main
# 2025-11-26 13:16:01  Evercore ISI Group    Outperform    Outperform   main
# 2025-11-26 11:50:20   B of A Securities           Buy           Buy   main
# 2025-11-26 11:30:35           Benchmark           Buy           Buy   reit
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-26 18:01:29            Raises               258.0             249.0
# 2025-11-26 17:19:29            Raises               275.0             250.0
# 2025-11-26 16:15:50            Raises               320.0             310.0
# 2025-11-26 15:49:01            Raises               265.0             250.0
# 2025-11-26 14:51:03            Raises               293.0             288.0
# 2025-11-26 13:16:01            Lowers               282.0             303.0
# 2025-11-26 11:50:20            Raises               290.0             275.0
# 2025-11-26 11:30:35         Maintains               285.0             285.0
#
# --- Checking ADIL ---
# No actions for ADIL in 2025.
#
# --- Checking ADMA ---
# No actions for ADMA in 2025.
#
# --- Checking ADNT ---
#                             Firm       ToGrade     FromGrade Action  \
# GradeDate
# 2025-11-12 20:53:31    Citigroup       Neutral       Neutral   main
# 2025-11-07 15:00:39     Barclays  Equal-Weight  Equal-Weight   main
# 2025-11-06 22:06:56    JP Morgan       Neutral       Neutral   main
# 2025-11-06 18:08:08          UBS       Neutral       Neutral   main
# 2025-11-06 15:47:35  Wells Fargo    Overweight    Overweight   main
# 2025-11-06 13:09:54       Stifel           Buy           Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-12 20:53:31            Lowers                22.5              25.0
# 2025-11-07 15:00:39            Lowers                24.0              27.0
# 2025-11-06 22:06:56            Lowers                24.0              26.0
# 2025-11-06 18:08:08            Lowers                22.0              28.0
# 2025-11-06 15:47:35            Lowers                28.0              31.0
# 2025-11-06 13:09:54            Lowers                24.0              29.0
#
# --- Checking ADPT ---
#                                Firm       ToGrade     FromGrade Action  \
# GradeDate
# 2025-11-11 16:29:45  Morgan Stanley  Equal-Weight  Equal-Weight   main
# 2025-11-06 21:14:44       JP Morgan    Overweight    Overweight   main
# 2025-11-06 09:15:31            BTIG           Buy           Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-11 16:29:45            Raises                16.0              11.0
# 2025-11-06 21:14:44            Raises                20.0              17.0
# 2025-11-06 09:15:31            Raises                21.0              19.0
#
# --- Checking ADSK ---
#                                   Firm         ToGrade       FromGrade Action  \
# GradeDate
# 2025-11-26 17:40:28  B of A Securities         Neutral         Neutral   main
# 2025-11-26 17:33:19          Macquarie      Outperform      Outperform   main
# 2025-11-26 17:31:40        BMO Capital  Market Perform  Market Perform   main
# 2025-11-26 17:28:31              Baird      Outperform      Outperform   main
# 2025-11-26 15:55:42           Barclays      Overweight      Overweight   main
# 2025-11-26 15:51:22        Wells Fargo      Overweight      Overweight   main
# 2025-11-26 13:16:55         Rosenblatt             Buy             Buy   main
# 2025-11-26 12:10:07      Deutsche Bank             Buy            Hold     up
# 2025-11-24 17:29:09         Rosenblatt             Buy             Buy   main
# 2025-11-18 15:48:34              Baird      Outperform      Outperform   main
# 2025-11-14 19:38:36          Citigroup             Buy             Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-26 17:40:28            Raises               365.0             360.0
# 2025-11-26 17:33:19            Raises               400.0             380.0
# 2025-11-26 17:31:40            Raises               343.0             333.0
# 2025-11-26 17:28:31            Raises               377.0             367.0
# 2025-11-26 15:55:42            Raises               390.0             385.0
# 2025-11-26 15:51:22            Raises               380.0             375.0
# 2025-11-26 13:16:55            Raises               375.0             355.0
# 2025-11-26 12:10:07            Raises               375.0             345.0
# 2025-11-24 17:29:09         Maintains               355.0             355.0
# 2025-11-18 15:48:34            Raises               367.0             363.0
# 2025-11-14 19:38:36            Lowers               370.0             393.0
#
# --- Checking ADT ---
# No actions for ADT in 2025.
#
# --- Checking ADTN ---
#                            Firm ToGrade FromGrade Action priceTargetAction  \
# GradeDate
# 2025-11-05 13:09:44  Rosenblatt     Buy       Buy   main         Maintains
#
#                      currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-05 13:09:44                11.0              11.0
#
# --- Checking ADTX ---
# No actions for ADTX in 2025.
#
# --- Checking ADUS ---
#                             Firm         ToGrade    FromGrade Action  \
# GradeDate
# 2025-11-13 10:55:09  BMO Capital  Market Perform                init
# 2025-11-07 18:06:16  RBC Capital      Outperform   Outperform   main
# 2025-11-05 18:43:39     TD Cowen             Buy          Buy   main
# 2025-11-04 13:56:55     Barclays     Underweight  Underweight   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-13 10:55:09         Announces               120.0               0.0
# 2025-11-07 18:06:16            Raises               139.0             134.0
# 2025-11-05 18:43:39            Raises               140.0             139.0
# 2025-11-04 13:56:55            Raises               117.0             111.0
#
# --- Checking ADV ---
# No actions for ADV in 2025.
#
# --- Checking ADVM ---
#                                     Firm  ToGrade FromGrade Action  \
# GradeDate
# 2025-11-17 11:54:19  HC Wainwright & Co.  Neutral       Buy   down
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-17 11:54:19            Lowers                 5.0              30.0
#
# --- Checking AEE ---
# No actions for AEE in 2025.
#
# --- Checking AEIS ---
#                             Firm       ToGrade     FromGrade Action  \
# GradeDate
# 2025-11-12 20:21:58    Citigroup           Buy           Buy   main
# 2025-11-05 18:26:01     TD Cowen          Hold          Hold   main
# 2025-11-05 15:48:08  Wells Fargo  Equal-Weight  Equal-Weight   main
# 2025-11-05 14:15:55    Benchmark           Buy           Buy   main
# 2025-11-05 12:51:47       Stifel           Buy           Buy   main
# 2025-11-05 12:45:35      Keybanc    Overweight    Overweight   main
# 2025-11-05 11:09:15      Needham           Buy           Buy   main
#
#                     priceTargetAction  currentPriceTarget  priorPriceTarget
# GradeDate
# 2025-11-12 20:21:58            Raises               255.0             167.0
# 2025-11-05 18:26:01            Raises               210.0             140.0
# 2025-11-05 15:48:08            Raises               215.0             175.0
# 2025-11-05 14:15:55            Raises               225.0             150.0
# 2025-11-05 12:51:47            Raises               230.0             210.0
# 2025-11-05 12:45:35            Raises               240.0             195.0
# 2025-11-05 11:09:15            Raises               225.0             188.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 30
#      27     print(f"Error fetching {symbol}: {e}")
#      29 # 3. CRITICAL: Sleep for 1 second to avoid getting banned
# ---> 30 time.sleep(1)
#
# KeyboardInterrupt:
